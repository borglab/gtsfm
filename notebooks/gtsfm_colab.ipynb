# %%
! git clone --recursive https://github.com/borglab/gtsfm
# %cd gtsfm
# Out:
# Cloning into 'gtsfm'...
# remote: Enumerating objects: 40310, done.
# remote: Counting objects: 100% (808/808), done.
# remote: Compressing objects: 100% (347/347), done.
# remote: Total 40310 (delta 624), reused 479 (delta 461), pack-reused 39502 (from 3)
# Receiving objects: 100% (40310/40310), 404.93 MiB | 29.13 MiB/s, done.
# Resolving deltas: 100% (28986/28986), done.
# Submodule 'thirdparty/LightGlue' (https://github.com/cvg/LightGlue.git) registered for path 'thirdparty/LightGlue'
# Submodule 'thirdparty/mast3r' (https://github.com/naver/mast3r.git) registered for path 'thirdparty/mast3r'
# Cloning into '/content/gtsfm/thirdparty/LightGlue'...
# remote: Enumerating objects: 411, done.
# remote: Counting objects: 100% (260/260), done.
# remote: Compressing objects: 100% (130/130), done.
# remote: Total 411 (delta 199), reused 130 (delta 130), pack-reused 151 (from 1)
# Receiving objects: 100% (411/411), 13.68 MiB | 23.24 MiB/s, done.
# Resolving deltas: 100% (260/260), done.
# ...

# %%
# !bash colab/install_dependencies.sh
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 20.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
# ERROR: Ignored the following versions that require a different python version: 1.9.5 Requires-Python !=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*,<3.7,>=2.7
# ERROR: Could not find a version that satisfies the requirement pydegensac (from versions: none)
# ERROR: No matching distribution found for pydegensac
# ...
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 https://cli.github.com/packages stable InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# ...

# %%
! pip install -e .
# Out:
# Obtaining file:///content/gtsfm
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for gtsfm (pyproject.toml) ... done
#   Created wheel for gtsfm: filename=gtsfm-0.2.0-0.editable-py3-none-any.whl size=8436 sha256=747529681390bd58008793b9cbfbd0a7309f7eec61fc178fda1a2b90b58189f8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8io4kj67/wheels/31/b4/3a/60fefbee39aa6da2a84cd089341d0e54cbd495dc743ade6435
# Successfully built gtsfm
# ...
#   Attempting uninstall: gtsfm
#     Found existing installation: gtsfm 0.2.0
#     Uninstalling gtsfm-0.2.0:
#       Successfully uninstalled gtsfm-0.2.0
# ...

# %%
# test case
import gtsfm;
import gtsam;
print('Welcome to GTSFM')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-634502019.py in <cell line: 0>()
#       1 # test case
#       2 import gtsfm;
# ----> 3 import gtsam;
#       4 print('Welcome to GTSFM')
#
# ModuleNotFoundError: No module named 'gtsam'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
! python gtsfm/runner/run_scene_optimizer_olssonloader.py --dataset_root tests/data/set1_lund_door --config_name sift_front_end.yaml --num_workers 1 --mvs_off
# Out:
# /content/gtsfm/gtsfm/runner/gtsfm_runner_base.py:164: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   with hydra.initialize_config_module(config_module="gtsfm.configs"):
# --2025-02-14 15:28:08--  https://cvg-data.inf.ethz.ch/hloc/netvlad/Pitts30K_struct.mat
# Resolving cvg-data.inf.ethz.ch (cvg-data.inf.ethz.ch)... 129.132.114.72
# Connecting to cvg-data.inf.ethz.ch (cvg-data.inf.ethz.ch)|129.132.114.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 554551295 (529M)
# Saving to: ‘/content/gtsfm/thirdparty/hloc/weights/VGG16-NetVLAD-Pitts30K.mat’
#
# /content/gtsfm/thir 100%[===================>] 528.86M  28.4MB/s    in 21s
#
# 2025-02-14 15:28:30 (25.1 MB/s) - ‘/content/gtsfm/thirdparty/hloc/weights/VGG16-NetVLAD-Pitts30K.mat’ saved [554551295/554551295]
#
# [2025-02-14 15:28:40,124 INFO gtsfm_runner_base.py line 241 3408]
#
# ...

# %%
from colab.plot import *

colmap_results_folder = "/content/gtsfm/results/ba_output"
plot(colmap_results_folder)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e70ff1ec869e> in <cell line: 0>()
# ----> 1 from colab.plot import *
#       2
#       3 colmap_results_folder = "/content/gtsfm/results/ba_output"
#       4 plot(colmap_results_folder)
#
# ModuleNotFoundError: No module named 'colab'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
